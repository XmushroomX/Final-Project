# %% [markdown]
# ## Crawl post từ page

# %%
# %pip install facebook_scraper pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np

# %%
FANPAGE_LINK ="warriors"
FOLDER_PATH = "Data/"
COOKIE_PATH = "./www.facebook.com_cookies.txt"

PAGES_NUMBER = 12

# %%
post_list = []
for post in get_posts(FANPAGE_LINK, 
                    options={"comments": True, "reactions": True, "allow_extra_requests": True}, 
                    extra_info=True, pages=12, cookies=COOKIE_PATH):
    post_list.append(post)
# Out:
# c:\Users\dangv\anaconda3\Lib\site-packages\facebook_scraper\facebook_scraper.py:855: UserWarning: Facebook language detected as vi_VN - for best results, set to en_US
#   warnings.warn(
# Traceback (most recent call last):
#   File "c:\Users\dangv\anaconda3\Lib\site-packages\facebook_scraper\utils.py", line 279, in safe_consume
#     for item in generator:
#   File "c:\Users\dangv\anaconda3\Lib\site-packages\facebook_scraper\extractors.py", line 708, in extract_reactors
#     data = json.loads(response.text[prefix_length:])  # Strip 'for (;;);'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dangv\anaconda3\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dangv\anaconda3\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## Save data

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(path, index=False)
print(path)

# %%
post_df_full
# Out:
#               post_id                                               text  \
# 0    1041169967373914  "He's a true hooper, so obviously he's going t...
# 1    1040740404083537  In-Season Tournament matchup against the Kings...
# 2    1040651337425777  The Dubs have 44 dunks so far this season, res...
# 3    1040647317426179  Play that back one time ▶️\n\nVerizon || Plays...
# 4    1040625064095071  "Yes, sir. Yes, sir. Yes, sir!"\n\nStephen Cur...
# ..                ...                                                ...
# 115  1032642574893320    Career-high points for the rook before the half
# 116  1032637014893876  Behind-the-back to the rack\nthat's nice, Dari...
# 117  1032634171560827  12 points in 12 minutes\nBrandin' is BALLING\n...
# 118  1032632371561007                                       Tough bucket
# 119  1032626498228261       Beat the buzzer ✅\n\nĐánh bay tiếng chuông ✅
#
#                                              post_text shared_text  \
# ...
